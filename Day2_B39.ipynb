# %%
introduction to variable in python:

# %%
x = 3
y = 5

# %%
x+y
# Out:
# 8

# %%
rules for declaring the variables in python:

# %%
rule no 1: no namespaces while declaring the variable name.

# %%
first name = "joshua"
print(first name)
# Out:
#   File "<ipython-input-5-21f20f070444>", line 1
#     first name = "joshua"
#           ^
# SyntaxError: invalid syntax

# %%
firstname = "joshua"
print(firstname)
# Out:
# joshua

# %%
first_name = "joshua"
print(first_name)
# Out:
# joshua

# %%
rule no 2 : variable name should not start with a number.

# %%
1name = "joshua"
print(1name)
# Out:
#   File "<ipython-input-8-ca3579abcba1>", line 1
#     1name = "joshua"
#      ^
# SyntaxError: invalid syntax

# %%
name1 = 'joshua'
print(name1)
# Out:
# joshua

# %%
rule no 3 : variable name should not include any special characters
    @$&%*

# %%
name@ ='joshua'
print(name@)
# Out:
#   File "<ipython-input-10-5c3acdca85ed>", line 1
#     name@ ='joshua'
#           ^
# SyntaxError: invalid syntax

# %%
introduction to datatypes in python :

# %%
string --- str
number -----> integers(int) and floats(float)(decimals)
list----->
tuple------>
dictionaries ------> dict

# %%
note : python is case senstive language

# %%
classification of datatypes:

# %%
two different categories:
    1. mutable datatypes ------> which we can edit or alter 
    2.immutable-----> we cannot able to edit or alter

# %%
introduction to string datatypes :
    definition : a string is nothing byt a series of characters enclosed in quotes
    classification : it is an immutable datatype
    how to declare a string -----?
        3. possible ways for declaring a string
        1. single quotes
        2.double quotes
        3.triple quotes

# %%
name = 'joshua'
print(name) #single quote
# Out:
# joshua

# %%
name2 = "sam"
print(name) #double quote
# Out:
# joshua

# %%
name3 = """leo"""
print(name3) # triple quote
# Out:
# leo

# %%
introductoin to string methods:

# %%
# req:how to validate the datatype ====> type

# %%
type(name)
# Out:
# str

# %%
type(name1)
# Out:
# str

# %%
type(name3)
# Out:
# str

# %%
fullname = 'leo solomon'
print(fullname)
# Out:
# leo solomon

# %%
#req : to correct the above to the right format...

# %%
print(fullname.title())
# Out:
# Leo Solomon
