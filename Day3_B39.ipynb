# %%
continuation with strings

# %%
type 

title
upper

# %%
fullname = 'kiran kumar'
print(fullname)
# Out:
# kiran kumar

# %%
type(fullname)
# Out:
# str

# %%
print(fullname.title())
# Out:
# Kiran Kumar

# %%
# req : i want to convert the name in to capitals

# %%
print(fullname.upper())
# Out:
# KIRAN KUMAR

# %%
#req : i want to convert the name in the name in to small case

# %%
print(fullname.lower())
# Out:
# kiran kumar

# %%
introduction to f strings:

# %%
# general synntax of f strings

# %%
f"customwords, {placeholder1} {placeholder2}.......{placeholdern}"

# %%
firstname = 'Shazia '
lastname  = 'Sultana'

# %%
#req: i want to have the fullnam

# %%
fullname = f"{firstname} {lastname}"
print(fullname.title())
# Out:
# Shazia Sultana

# %%
# req: i want to greet the user...

# %%
x = f"hello, {fullname.title()}"
print(x)
# Out:
# hello, Shazia Sultana

# %%
adding whitespaces to spring:

# %%
# req: i want to collect the fav prog language survey among the group of students..

# %%
print("fav_language:pythonjavacc#c++")
# Out:
# fav_language:pythonjavac#c++

# %%
\n ------> new line delimiter

# %%
print("fav_language:\npython\njava\nc\nc#\nc++")
# Out:
# fav_language:
# python
# java
# c
# c#
# c++

# %%
print("fav_language:\n\tpython\n\tjava\n\tc\n\tc#\n\tc++") # \t--> tab delimiter
# Out:
# fav_language:
# 	python
# 	java
# 	c
# 	c#
# 	c++

# %%
removing whitespaces from string:

# %%
name = 'python'#valid
print(name)
# Out:
# python

# %%
name1 = 'python  '#gap is on the right side
print(name1)
# Out:
# python

# %%
name2 = ' python' #gap is on the left side...
print(name2)
# Out:
#  python

# %%
name1.rstrip()
# Out:
# 'python'

# %%
 name2.lstrip()
# Out:
# 'python'

# %%
name3 = '   python   ' 
print(name3)
# Out:
#    python

# %%
name3.strip()
# Out:
# 'python'
