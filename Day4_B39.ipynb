# %%
introduction to list datatypes:

# %%
defintioin : a list is a collectioin of items in a particular order.
classiication : it is classified as mutable datatype
how do you define a list : -----> []

# %%
students = ['ravi', 'priyanka', 'afsha', 'anushka', 'nadeem', 'shazia']# 0,1,2,3,4,5,6

# %%
print(students)
# Out:
# ['ravi', 'priyanka', 'afsha', 'anushka', 'nadeem', 'shazia']

# %%
type(students)
# Out:
# list

# %%
# how to access the elements from the above list...?

# %%
introduction to indexing : 0,1,2,3......

# %%
# req: i want to acess ravi in the output...?

# %%
print(students[0])
# Out:
# ravi

# %%
print(students[0].title())
# Out:
# Ravi

# %%
print(students[4].title())
# Out:
# Nadeem

# %%
1. how to add new elements in the list
2. how to modify the elements in the list
3. how to delete the elements in the list

# %%
#req : i want to add ankit in the list...?

# %%
students.append('ankit')

# %%
print(students)
# Out:
# ['ravi', 'priyanka', 'afsha', 'anushka', 'nadeem', 'shazia', 'ankit']

# %%
#req : i want to add radhika to the above list

# %%
students.append('radhika')

# %%
print(students)
# Out:
# ['ravi', 'priyanka', 'afsha', 'anushka', 'nadeem', 'shazia', 'ankit']

# %%
#req : i want to add tazeem at 2nd index...?

# %%
students.insert(2,'tazeem')

# %%
print(students)
# Out:
# ['ravi', 'priyanka', 'tazeem', 'afsha', 'anushka', 'nadeem', 'shazia', 'ankit']

# %%
print(students[2])
# Out:
# tazeem

# %%
itq : what is the diff btw append vs insert

# %%
2.how to modify the elements in the list

# %%
print(students)
# Out:
# ['ravi', 'priyanka', 'tazeem', 'afsha', 'anushka', 'nadeem', 'shazia', 'ankit']

# %%
# i want to replace/modify priyanka name to deepika

# %%
students[1] = 'deepiak'
print(students)
# Out:
# ['ravi', 'deepiak', 'tazeem', 'afsha', 'anushka', 'nadeem', 'shazia', 'ankit']

# %%
3.how to delete elements in the list

# %%
print(students)
# Out:
# ['ravi', 'deepiak', 'tazeem', 'afsha', 'anushka', 'nadeem', 'shazia', 'ankit']

# %%
# req: i want to delete ravi name from the ablove list...?

# %%
del students[0]
print(students)
# Out:
# ['tazeem', 'afsha', 'anushka', 'nadeem', 'shazia', 'ankit']

# %%
one more approach of deleting the elements from the list:
    temp approach ---> it will be not be deleting the elements permanently but it will be creating carboncopy of the deleted items.

# %%
print(students)
# Out:
# ['tazeem', 'afsha', 'anushka', 'nadeem', 'shazia', 'ankit']

# %%
x = students.pop()
print(students)
# Out:
# ['tazeem', 'afsha', 'anushka', 'nadeem', 'shazia']

# %%
print(x)
# Out:
# ankit

# %%
y = students.pop(2)
print(students)
# Out:
# ['tazeem', 'afsha', 'nadeem', 'shazia']

# %%
print(y)
# Out:
# anushka

# %%
int : what is the diff btw delete and pop method...
